# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET


# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceInfo'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '10',
    'pageNo': '1',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190215'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 데이터 추출 및 DataFrame으로 변환
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

df = pd.DataFrame(data, columns=columns)
print(df)
# Out:
#       rdate        srcode                    title
# 0  20230530  20230531-002                적조정보(무해성)
# 1  20230526  20230531-001     적조정보(무해성) 2023.05.26
# 2  20220925  20220925-001  적조속보(코클로디니움) 2022.09.25
# 3  20220922  20220922-001  적조속보(코클로디니움) 2022.09.22
# 4  20220921  20220921-001  적조속보(코클로디니움) 2022.09.21
# 5  20220919  20220919-001  적조속보(코클로디니움) 2022.09.19
# 6  20220918  20220918-001  적조속보(코클로디니움) 2022.09.18
# 7  20220917  20220917-001  적조속보(코클로디니움) 2022.09.17
# 8  20220916  20220916-004  적조속보(코클로디니움) 2022.09.16
# 9  20220913  20220913-001  적조속보(코클로디니움) 2022.09.13

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '1',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190215'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# Out:
#                          dname edensity   ewt              oarea   regdate  \
# 0                Noctiluca sp.     3000  20.2  울산 울주 온산항 신항 남방파제  20190517
# 1           Akashiwo sanguinea     1000  15.5         경남 통영시 영운리  20181204
# 2            Mesodinium rubrum      480  20.2             경남 거제시  20181019
# 3            Mesodinium rubrum     3500     0             전남 완도군  20180928
# 4            Mesodinium rubrum     4000  23.5             전남 장흥군  20180922
# ..                         ...      ...   ...                ...       ...
# 95  Cochlodinium polykrikoides      560  27.5         경남 거제시 동부면  20180802
# 96  Cochlodinium polykrikoides     1200  27.5         경남 거제시 동부면  20180802
# 97  Cochlodinium polykrikoides     1800  27.5         경남 거제시 동부면  20180802
# 98  Cochlodinium polykrikoides     1680  27.5         경남 거제시 동부면  20180802
# 99  Cochlodinium polykrikoides      700  27.2      전남 고흥군 동일면 상부  20180801
#
#    sdensity        srcode   swt
# 0         0  20190520-001  20.2
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '1',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190215'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
df.to_csv('red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt              oarea   regdate  \
# 0                Noctiluca sp.     3000  20.2  울산 울주 온산항 신항 남방파제  20190517
# 1           Akashiwo sanguinea     1000  15.5         경남 통영시 영운리  20181204
# 2            Mesodinium rubrum      480  20.2             경남 거제시  20181019
# 3            Mesodinium rubrum     3500     0             전남 완도군  20180928
# 4            Mesodinium rubrum     4000  23.5             전남 장흥군  20180922
# ..                         ...      ...   ...                ...       ...
# 95  Cochlodinium polykrikoides      560  27.5         경남 거제시 동부면  20180802
# 96  Cochlodinium polykrikoides     1200  27.5         경남 거제시 동부면  20180802
# 97  Cochlodinium polykrikoides     1800  27.5         경남 거제시 동부면  20180802
# 98  Cochlodinium polykrikoides     1680  27.5         경남 거제시 동부면  20180802
# 99  Cochlodinium polykrikoides      700  27.2      전남 고흥군 동일면 상부  20180801
#
#    sdensity        srcode   swt
# 0         0  20190520-001  20.2
# ...

# %%
df.head(30)
# Out:
#                          dname edensity   ewt                     oarea  \
# 0                Noctiluca sp.     3000  20.2         울산 울주 온산항 신항 남방파제
# 1           Akashiwo sanguinea     1000  15.5                경남 통영시 영운리
# 2            Mesodinium rubrum      480  20.2                    경남 거제시
# 3            Mesodinium rubrum     3500     0                    전남 완도군
# 4            Mesodinium rubrum     4000  23.5                    전남 장흥군
# 5                Noctiluca sp.     1532  22.8                전남 신안군 흑산면
# 6              Gymnodinium sp.      300     0                전남 완도군 소안면
# 7            Mesodinium rubrum     1200  21.2             전남 완도군 청산도 동측
# 8            Mesodinium rubrum      700  23.3                전남 완도군 망석리
# 9                Noctiluca sp.     8000     0             전남 완도군 금일읍 장도
# 10       Gymnodinium catenatum      870    23           전남 여수시 삼산면 거문도
# 11               Noctiluca sp.        0     0                경북 울진군 후포항
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '1',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20180801'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
df.to_csv('red_tide_data1.csv', index=False)
# Out:
#                          dname edensity   ewt              oarea   regdate  \
# 0                Noctiluca sp.     3000  20.2  울산 울주 온산항 신항 남방파제  20190517
# 1           Akashiwo sanguinea     1000  15.5         경남 통영시 영운리  20181204
# 2            Mesodinium rubrum      480  20.2             경남 거제시  20181019
# 3            Mesodinium rubrum     3500     0             전남 완도군  20180928
# 4            Mesodinium rubrum     4000  23.5             전남 장흥군  20180922
# ..                         ...      ...   ...                ...       ...
# 95  Cochlodinium polykrikoides      560  27.5         경남 거제시 동부면  20180802
# 96  Cochlodinium polykrikoides     1200  27.5         경남 거제시 동부면  20180802
# 97  Cochlodinium polykrikoides     1800  27.5         경남 거제시 동부면  20180802
# 98  Cochlodinium polykrikoides     1680  27.5         경남 거제시 동부면  20180802
# 99  Cochlodinium polykrikoides      700  27.2      전남 고흥군 동일면 상부  20180801
#
#    sdensity        srcode   swt
# 0         0  20190520-001  20.2
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '2',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20180731'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
df.to_csv('red_tide_data2.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides     1000  27.2
# 1   Cochlodinium polykrikoides     1000  27.2
# 2   Cochlodinium polykrikoides     1200  27.2
# 3   Cochlodinium polykrikoides      940  27.2
# 4   Cochlodinium polykrikoides     1850  27.2
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides      320  28.2
# 96  Cochlodinium polykrikoides      890  28.2
# 97  Cochlodinium polykrikoides        5  28.2
# 98  Cochlodinium polykrikoides      320  30.2
# 99  Cochlodinium polykrikoides      890  30.2
#
#                                                 oarea   regdate sdensity  \
# 0                                       전남 고흥군 동일면 상부  20180801      100
# 1                                       전남 고흥군 동일면 상부  20180801       40
# 2                                       전남 고흥군 동일면 상부  20180801       40
# 3                                       전남 고흥군 동일면 상부  20180801       10
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '3',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20180731'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
df.to_csv('red_tide_data3.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides        5  30.2
# 1   Cochlodinium polykrikoides      320  27.5
# 2   Cochlodinium polykrikoides      890  27.5
# 3   Cochlodinium polykrikoides        5  27.5
# 4   Cochlodinium polykrikoides      650  29.1
# ..                         ...      ...   ...
# 95      Chaetoceros curvisetus     1250  22.9
# 96      Leptocylindrus danicus     1650  22.9
# 97      Chaetoceros curvisetus      650  22.9
# 98      Leptocylindrus danicus     1500  22.9
# 99      Chaetoceros curvisetus      480  22.9
#
#                                                 oarea   regdate sdensity  \
# 0   전남 여수시 남면 우학리, 대유, 함구미, 용두, 화태, 월호수도, 돌산 두문포, ...  20180726        1
# 1                                  남해군 서면 장항, 미조면 본촌   20180726       10
# 2                                  남해군 서면 장항, 미조면 본촌   20180726       20
# 3                                  남해군 서면 장항, 미조면 본촌   20180726        1
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '4',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20180731'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
df.to_csv('red_tide_data4.csv', index=False)
# Out:
#                  dname   ewt oarea       regdate        srcode   swt  \
# 0                   없음  23.6  월호수도      20180711  20180711-001  23.6
# 1                   없음  23.6  월호수도      20180711  20180711-001  23.6
# 2                   없음  23.6  월호수도      20180711  20180711-001  23.6
# 3                   없음  23.6  월호수도      20180711  20180711-001  23.6
# 4                   없음  23.6  월호수도      20180711  20180711-001  23.6
# ..                 ...   ...   ...           ...           ...   ...
# 95  Akashiwo sanguinea  1500  21.7     부산 가덕도 동측      20180604  1500
# 96  Akashiwo sanguinea  2500  20.9  부산 가덕도 대항 동측      20180604  2500
# 97  Akashiwo sanguinea  1500  20.9  부산 가덕도 대항 동측      20180604  1500
# 98  Akashiwo sanguinea  1800  17.9    부산 가덕도 남동측      20180530  1800
# 99  Akashiwo sanguinea  2600  17.9    부산 가덕도 남동측      20180530  2600
#
#         edensity sdensity
# 0           None     None
# 1           None     None
# 2           None     None
# 3           None     None
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '5',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20180731'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
df.to_csv('red_tide_data5.csv', index=False)
# Out:
#                  dname edensity                    ewt             oarea  \
# 0   Akashiwo sanguinea       14                   17.9        부산 가덕도 남동측
# 1   Akashiwo sanguinea     1800                   17.9         부산 신자도 남측
# 2   Akashiwo sanguinea     2600                   17.9         부산 신자도 남측
# 3   Akashiwo sanguinea       14                   17.9         부산 신자도 남측
# 4   Akashiwo sanguinea     1800                   21.4          부산 서도 서측
# ..                 ...      ...                    ...               ...
# 95     Alexandrium sp.    11000                   28.1  경남 남해 남면, 미조, 창선
# 96     Alexandrium sp.    15000  경남 통영 오비도, 곤리도, 명지~함박          20170810
# 97     Alexandrium sp.     2500  경남 통영 오비도, 곤리도, 명지~함박          20170810
# 98     Alexandrium sp.    11000  경남 통영 오비도, 곤리도, 명지~함박          20170810
# 99     Alexandrium sp.     4000                     32        경남 통영 산양해역
#
#      regdate    sdensity        srcode   swt
# 0   20180530          14  20180531-001  17.9
# ...

# %%
import requests
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 최대 100으로 설정
    'pageNo': '1',
    'startYmd': '20150101',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20230712'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 'items' 요소의 하위에 있는 'item' 요소 개수 확인
items = root.find('body').find('items')
item_count = len(items.findall('item'))

print("한 페이지에 포함된 데이터 개수:", item_count)
# Out:
# 한 페이지에 포함된 데이터 개수: 100

# %%
import requests
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 최대 100으로 설정
    'pageNo': '1',
    'startYmd': '20150101',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20230712'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 'totalCount' 값을 가져오기
total_count = int(root.find('body').find('totalCount').text)

# 한 페이지에 가져올 수 있는 데이터 수
num_of_rows = int(params['numOfRows'])

# 총 페이지 수 계산
total_pages = (total_count + num_of_rows - 1) // num_of_rows

print("총 페이지 수:", total_pages)
# Out:
# 총 페이지 수: 245

# %%
import requests
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 최대 100으로 설정
    'pageNo': '55',
    'startYmd': '20150101',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20230712'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 데이터의 기간 추출
items = root.find('body').find('items')
start_date = items[0].findtext('regdate')  # 첫 번째 데이터의 기간
end_date = items[-1].findtext('regdate')  # 마지막 데이터의 기간

print("데이터의 기간:", start_date, "부터", end_date, "까지")
# Out:
# 데이터의 기간: 20130814 부터 20130814 까지

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '1',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('1red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt              oarea   regdate  \
# 0                Noctiluca sp.     3000  20.2  울산 울주 온산항 신항 남방파제  20190517
# 1           Akashiwo sanguinea     1000  15.5         경남 통영시 영운리  20181204
# 2            Mesodinium rubrum      480  20.2             경남 거제시  20181019
# 3            Mesodinium rubrum     3500     0             전남 완도군  20180928
# 4            Mesodinium rubrum     4000  23.5             전남 장흥군  20180922
# ..                         ...      ...   ...                ...       ...
# 95  Cochlodinium polykrikoides      560  27.5         경남 거제시 동부면  20180802
# 96  Cochlodinium polykrikoides     1200  27.5         경남 거제시 동부면  20180802
# 97  Cochlodinium polykrikoides     1800  27.5         경남 거제시 동부면  20180802
# 98  Cochlodinium polykrikoides     1680  27.5         경남 거제시 동부면  20180802
# 99  Cochlodinium polykrikoides      700  27.2      전남 고흥군 동일면 상부  20180801
#
#    sdensity        srcode   swt
# 0         0  20190520-001  20.2
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '2',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('2red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides     1000  27.2
# 1   Cochlodinium polykrikoides     1000  27.2
# 2   Cochlodinium polykrikoides     1200  27.2
# 3   Cochlodinium polykrikoides      940  27.2
# 4   Cochlodinium polykrikoides     1850  27.2
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides      320  28.2
# 96  Cochlodinium polykrikoides      890  28.2
# 97  Cochlodinium polykrikoides        5  28.2
# 98  Cochlodinium polykrikoides      320  30.2
# 99  Cochlodinium polykrikoides      890  30.2
#
#                                                 oarea   regdate sdensity  \
# 0                                       전남 고흥군 동일면 상부  20180801      100
# 1                                       전남 고흥군 동일면 상부  20180801       40
# 2                                       전남 고흥군 동일면 상부  20180801       40
# 3                                       전남 고흥군 동일면 상부  20180801       10
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '3',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('3red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides        5  30.2
# 1   Cochlodinium polykrikoides      320  27.5
# 2   Cochlodinium polykrikoides      890  27.5
# 3   Cochlodinium polykrikoides        5  27.5
# 4   Cochlodinium polykrikoides      650  29.1
# ..                         ...      ...   ...
# 95      Chaetoceros curvisetus     1250  22.9
# 96      Leptocylindrus danicus     1650  22.9
# 97      Chaetoceros curvisetus      650  22.9
# 98      Leptocylindrus danicus     1500  22.9
# 99      Chaetoceros curvisetus      480  22.9
#
#                                                 oarea   regdate sdensity  \
# 0   전남 여수시 남면 우학리, 대유, 함구미, 용두, 화태, 월호수도, 돌산 두문포, ...  20180726        1
# 1                                  남해군 서면 장항, 미조면 본촌   20180726       10
# 2                                  남해군 서면 장항, 미조면 본촌   20180726       20
# 3                                  남해군 서면 장항, 미조면 본촌   20180726        1
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '4',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('4red_tide_data.csv', index=False)
# Out:
#                  dname   ewt oarea       regdate        srcode   swt  \
# 0                   없음  23.6  월호수도      20180711  20180711-001  23.6
# 1                   없음  23.6  월호수도      20180711  20180711-001  23.6
# 2                   없음  23.6  월호수도      20180711  20180711-001  23.6
# 3                   없음  23.6  월호수도      20180711  20180711-001  23.6
# 4                   없음  23.6  월호수도      20180711  20180711-001  23.6
# ..                 ...   ...   ...           ...           ...   ...
# 95  Akashiwo sanguinea  1500  21.7     부산 가덕도 동측      20180604  1500
# 96  Akashiwo sanguinea  2500  20.9  부산 가덕도 대항 동측      20180604  2500
# 97  Akashiwo sanguinea  1500  20.9  부산 가덕도 대항 동측      20180604  1500
# 98  Akashiwo sanguinea  1800  17.9    부산 가덕도 남동측      20180530  1800
# 99  Akashiwo sanguinea  2600  17.9    부산 가덕도 남동측      20180530  2600
#
#         edensity sdensity
# 0           None     None
# 1           None     None
# 2           None     None
# 3           None     None
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '5',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('5red_tide_data.csv', index=False)
# Out:
#                  dname edensity                    ewt             oarea  \
# 0   Akashiwo sanguinea       14                   17.9        부산 가덕도 남동측
# 1   Akashiwo sanguinea     1800                   17.9         부산 신자도 남측
# 2   Akashiwo sanguinea     2600                   17.9         부산 신자도 남측
# 3   Akashiwo sanguinea       14                   17.9         부산 신자도 남측
# 4   Akashiwo sanguinea     1800                   21.4          부산 서도 서측
# ..                 ...      ...                    ...               ...
# 95     Alexandrium sp.    11000                   28.1  경남 남해 남면, 미조, 창선
# 96     Alexandrium sp.    15000  경남 통영 오비도, 곤리도, 명지~함박          20170810
# 97     Alexandrium sp.     2500  경남 통영 오비도, 곤리도, 명지~함박          20170810
# 98     Alexandrium sp.    11000  경남 통영 오비도, 곤리도, 명지~함박          20170810
# 99     Alexandrium sp.     4000                     32        경남 통영 산양해역
#
#      regdate    sdensity        srcode   swt
# 0   20180530          14  20180531-001  17.9
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '6',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('6red_tide_data.csv', index=False)
# Out:
#                          dname edensity    ewt                oarea   regdate  \
# 0              Alexandrium sp.     4000     32           경남 통영 산양해역  20170809
# 1              Alexandrium sp.     4000   27.9  경남 남해 서면~남면, 미조, 창선  20170809
# 2              Alexandrium sp.     4000   27.9  경남 남해 서면~남면, 미조, 창선  20170809
# 3              Alexandrium sp.     1500   28.2    경남 통영시 학림~연명, 곤리도  20170807
# 4             Chaetoceros spp.     6000  22.21     경남 통영 곤리도 ~ 학림해역  20170728
# ..                         ...      ...    ...                  ...       ...
# 95           Karenia mikimotoi      690   27.2    전남 완도군 신지, 약산, 금일  20160821
# 96           Karenia mikimotoi      510   27.2    전남 완도군 신지, 약산, 금일  20160821
# 97           Karenia mikimotoi      640   27.2    전남 완도군 신지, 약산, 금일  20160821
# 98  Cochlodinium polykrikoides     1350   27.2    전남 완도군 신지, 약산, 금일  20160821
# 99           Karenia mikimotoi      690   27.9   전남 고흥군 소록도~거금도~도화면  20160821
#
#    sdensity      srcode   swt
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '4',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('44red_tide_data.csv', index=False)
# Out:
#                  dname   ewt oarea       regdate        srcode   swt  \
# 0                   없음  23.6  월호수도      20180711  20180711-001  23.6
# 1                   없음  23.6  월호수도      20180711  20180711-001  23.6
# 2                   없음  23.6  월호수도      20180711  20180711-001  23.6
# 3                   없음  23.6  월호수도      20180711  20180711-001  23.6
# 4                   없음  23.6  월호수도      20180711  20180711-001  23.6
# ..                 ...   ...   ...           ...           ...   ...
# 95  Akashiwo sanguinea  1500  21.7     부산 가덕도 동측      20180604  1500
# 96  Akashiwo sanguinea  2500  20.9  부산 가덕도 대항 동측      20180604  2500
# 97  Akashiwo sanguinea  1500  20.9  부산 가덕도 대항 동측      20180604  1500
# 98  Akashiwo sanguinea  1800  17.9    부산 가덕도 남동측      20180530  1800
# 99  Akashiwo sanguinea  2600  17.9    부산 가덕도 남동측      20180530  2600
#
#         edensity sdensity
# 0           None     None
# 1           None     None
# 2           None     None
# 3           None     None
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '6',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('66red_tide_data.csv', index=False)
# Out:
#                          dname edensity    ewt                oarea   regdate  \
# 0              Alexandrium sp.     4000     32           경남 통영 산양해역  20170809
# 1              Alexandrium sp.     4000   27.9  경남 남해 서면~남면, 미조, 창선  20170809
# 2              Alexandrium sp.     4000   27.9  경남 남해 서면~남면, 미조, 창선  20170809
# 3              Alexandrium sp.     1500   28.2    경남 통영시 학림~연명, 곤리도  20170807
# 4             Chaetoceros spp.     6000  22.21     경남 통영 곤리도 ~ 학림해역  20170728
# ..                         ...      ...    ...                  ...       ...
# 95           Karenia mikimotoi      690   27.2    전남 완도군 신지, 약산, 금일  20160821
# 96           Karenia mikimotoi      510   27.2    전남 완도군 신지, 약산, 금일  20160821
# 97           Karenia mikimotoi      640   27.2    전남 완도군 신지, 약산, 금일  20160821
# 98  Cochlodinium polykrikoides     1350   27.2    전남 완도군 신지, 약산, 금일  20160821
# 99           Karenia mikimotoi      690   27.9   전남 고흥군 소록도~거금도~도화면  20160821
#
#    sdensity      srcode   swt
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '7',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('7red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt               oarea   regdate  \
# 0            Karenia mikimotoi      510  27.9  전남 고흥군 소록도~거금도~도화면  20160821
# 1            Karenia mikimotoi      640  27.9  전남 고흥군 소록도~거금도~도화면  20160821
# 2   Cochlodinium polykrikoides     1350  27.9  전남 고흥군 소록도~거금도~도화면  20160821
# 3   Cochlodinium polykrikoides     1390  30.8          전남 장흥군 득량만  20160820
# 4            Karenia mikimotoi     1280  30.8          전남 장흥군 득량만  20160820
# ..                         ...      ...   ...                 ...       ...
# 95  Cochlodinium polykrikoides        6  29.6      전남 고흥군 거금, 소록도  20160815
# 96           Karenia mikimotoi      480  29.6      전남 고흥군 거금, 소록도  20160815
# 97           Karenia mikimotoi      480  29.6      전남 고흥군 거금, 소록도  20160815
# 98  Cochlodinium polykrikoides        6  29.1           전남 여수 백야도  20160815
# 99           Karenia mikimotoi      480  29.1           전남 여수 백야도  20160815
#
#    sdensity      srcode   swt
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '8',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('8red_tide_data.csv', index=False)
# Out:
#                          dname edensity                       ewt  \
# 0            Karenia mikimotoi      480                      29.1
# 1            Karenia mikimotoi      250                      30.9
# 2            Karenia mikimotoi      500                      28.2
# 3               Ceratium furca      500  부산시 강서구 가덕도 동쪽 대항~동두말 해역
# 4        Prorocentrum dentatum     3000                      19.2
# ..                         ...      ...                       ...
# 95  Cochlodinium polykrikoides      400                      22.9
# 96  Cochlodinium polykrikoides      640                      23.8
# 97  Cochlodinium polykrikoides     1800                      23.8
# 98  Cochlodinium polykrikoides     2800                      23.8
# 99  Cochlodinium polykrikoides      400                      23.8
#
#                                                 oarea   regdate    sdensity  \
# 0                                           전남 여수 백야도  20160815          90
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '9',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('9red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides      640  22.7
# 1   Cochlodinium polykrikoides     1800  22.7
# 2   Cochlodinium polykrikoides     2800  22.7
# 3   Cochlodinium polykrikoides      400  22.7
# 4   Cochlodinium polykrikoides      640  23.6
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides      440  24.3
# 96  Cochlodinium polykrikoides     1650  24.3
# 97  Cochlodinium polykrikoides      140  24.3
# 98  Cochlodinium polykrikoides     2450  24.3
# 99  Cochlodinium polykrikoides     1800  23.3
#
#                                           oarea   regdate sdensity  \
# 0   진도 고군~의신~임회, 해남 북평(남성)~송지(통호)~화산(상마)~황산(옥동)  20150916      110
# 1   진도 고군~의신~임회, 해남 북평(남성)~송지(통호)~화산(상마)~황산(옥동)  20150916      110
# 2   진도 고군~의신~임회, 해남 북평(남성)~송지(통호)~화산(상마)~황산(옥동)  20150916      370
# 3   진도 고군~의신~임회, 해남 북평(남성)~송지(통호)~화산(상마)~황산(옥동)  20150916       16
# 4      고흥 금산(우두~신촌, 오천~명천)~도양(화도~소록도)~도화(구암~지죽)  20150916      110
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '10',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('10red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides     1200  23.3
# 1   Cochlodinium polykrikoides      802  23.3
# 2   Cochlodinium polykrikoides      440  23.3
# 3   Cochlodinium polykrikoides     1650  23.3
# 4   Cochlodinium polykrikoides      140  23.3
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides     1500  25.4
# 96  Cochlodinium polykrikoides    10000  25.4
# 97  Cochlodinium polykrikoides      880  25.8
# 98  Cochlodinium polykrikoides     2400  25.8
# 99  Cochlodinium polykrikoides     3000  25.8
#
#                                                 oarea   regdate sdensity  \
# 0                        여수 두문포~향일암, 개도~월호, 용두~여천~우학리  20150912       30
# 1                        여수 두문포~향일암, 개도~월호, 용두~여천~우학리  20150912      117
# 2                        여수 두문포~향일암, 개도~월호, 용두~여천~우학리  20150912      100
# 3                        여수 두문포~향일암, 개도~월호, 용두~여천~우학리  20150912      120
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '11',
    'startYmd': '20151223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('11red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides     4100  25.8
# 1   Cochlodinium polykrikoides     2600  25.8
# 2   Cochlodinium polykrikoides     1500  25.8
# 3   Cochlodinium polykrikoides    10000  25.8
# 4   Cochlodinium polykrikoides      880  25.1
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides       50    23
# 96  Cochlodinium polykrikoides     1600  25.4
# 97  Cochlodinium polykrikoides     4750  25.4
# 98  Cochlodinium polykrikoides     3280  25.4
# 99  Cochlodinium polykrikoides       10  25.4
#
#                                                 oarea   regdate sdensity  \
# 0            강진 마량(수인~숙마), 장흥 관산(우산)~회진(대리~노력)~대덕(내저)  20150910      720
# 1            강진 마량(수인~숙마), 장흥 관산(우산)~회진(대리~노력)~대덕(내저)  20150910      100
# 2            강진 마량(수인~숙마), 장흥 관산(우산)~회진(대리~노력)~대덕(내저)  20150910      100
# 3            강진 마량(수인~숙마), 장흥 관산(우산)~회진(대리~노력)~대덕(내저)  20150910      200
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '12',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('12red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides      160  25.4
# 1   Cochlodinium polykrikoides     5000  25.4
# 2   Cochlodinium polykrikoides     4180  25.4
# 3   Cochlodinium polykrikoides      300  25.4
# 4   Cochlodinium polykrikoides     1600  25.3
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides     7000  25.5
# 96  Cochlodinium polykrikoides      400  25.5
# 97  Cochlodinium polykrikoides     1800  25.5
# 98  Cochlodinium polykrikoides     3200  25.5
# 99  Cochlodinium polykrikoides     1936  25.5
#
#                                                 oarea   regdate sdensity  \
# 0   완도 군의~신지(모항~송곡~동고)~약산(해동~어두리)~금일(일정~용항), 소안~망석...  20150908      160
# 1   완도 군의~신지(모항~송곡~동고)~약산(해동~어두리)~금일(일정~용항), 소안~망석...  20150908       10
# 2   완도 군의~신지(모항~송곡~동고)~약산(해동~어두리)~금일(일정~용항), 소안~망석...  20150908      870
# 3   완도 군의~신지(모항~송곡~동고)~약산(해동~어두리)~금일(일정~용항), 소안~망석...  20150908       30
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '13',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('13red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides     3800  25.5
# 1   Cochlodinium polykrikoides     6200  25.5
# 2   Cochlodinium polykrikoides     7000  24.7
# 3   Cochlodinium polykrikoides      400  24.7
# 4   Cochlodinium polykrikoides     1800  24.7
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides     3328  24.5
# 96  Cochlodinium polykrikoides     1000  24.5
# 97  Cochlodinium polykrikoides     7400  24.5
# 98  Cochlodinium polykrikoides     2500  24.5
# 99  Cochlodinium polykrikoides     1500  24.5
#
#                                                 oarea   regdate sdensity  \
# 0                   강진(수인~마량), 장흥 관산(장환~우산)~회진(대리~노력)  20150907       12
# 1                   강진(수인~마량), 장흥 관산(장환~우산)~회진(대리~노력)  20150907      120
# 2                고흥 금산(신촌~익금~명천)~도양(소록도~화도)~도화(구암~하동)  20150907       10
# 3                고흥 금산(신촌~익금~명천)~도양(소록도~화도)~도화(구암~하동)  20150907       30
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '14',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('14red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides      300  24.5
# 1   Cochlodinium polykrikoides     1020  24.6
# 2   Cochlodinium polykrikoides     3328  24.6
# 3   Cochlodinium polykrikoides     1000  24.6
# 4   Cochlodinium polykrikoides     7400  24.6
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides     1200  24.9
# 96  Cochlodinium polykrikoides     2100  25.1
# 97  Cochlodinium polykrikoides     2390  25.1
# 98  Cochlodinium polykrikoides    25000  25.1
# 99  Cochlodinium polykrikoides      144  25.1
#
#                                                 oarea   regdate sdensity  \
# 0   포항(영암~하정, 구룡포~강사, 오도~방어리), 영덕(부경~강구, 창포~축산), 울...  20150905      150
# 1                   고흥 금산(신촌~명천)~도양(장예~화도)~도화(구암)\r\n  20150905       10
# 2                   고흥 금산(신촌~명천)~도양(장예~화도)~도화(구암)\r\n  20150905       16
# 3                   고흥 금산(신촌~명천)~도양(장예~화도)~도화(구암)\r\n  20150905      500
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '15',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('15red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides      800  25.1
# 1   Cochlodinium polykrikoides     1200  25.1
# 2   Cochlodinium polykrikoides     2100  23.6
# 3   Cochlodinium polykrikoides     2390  23.6
# 4   Cochlodinium polykrikoides    25000  23.6
# ..                         ...      ...   ...
# 95   Pheopolykrikos hartmannii     2200  25.5
# 96  Cochlodinium polykrikoides      120    24
# 97  Cochlodinium polykrikoides      800    24
# 98  Cochlodinium polykrikoides     2380    24
# 99  Cochlodinium polykrikoides     3500    24
#
#                                                 oarea   regdate sdensity  \
# 0                            울산 울주군(서생~온산), 북구(우가~신명)  20150903        4
# 1                            울산 울주군(서생~온산), 북구(우가~신명)  20150903       30
# 2   완도 소안(미라~부상), 청산 소모도, 신지(송곡~동고)~약산(득암~당목~어두)~금...  20150903      600
# 3   완도 소안(미라~부상), 청산 소모도, 신지(송곡~동고)~약산(득암~당목~어두)~금...  20150903       15
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '16',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('16red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides     2200    24
# 1   Cochlodinium polykrikoides     3100    24
# 2   Cochlodinium polykrikoides      120  24.8
# 3   Cochlodinium polykrikoides      800  24.8
# 4   Cochlodinium polykrikoides     2380  24.8
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides      120  27.1
# 96  Cochlodinium polykrikoides     2160  24.8
# 97  Cochlodinium polykrikoides      850  24.8
# 98  Cochlodinium polykrikoides     1600  24.8
# 99  Cochlodinium polykrikoides     1700  24.8
#
#                                                 oarea   regdate sdensity  \
# 0   완도 신지(송곡)~약산(득암), 약산(당목~어두리), 금일(칠기~도장), 소안(미라...  20150831       50
# 1   완도 신지(송곡)~약산(득암), 약산(당목~어두리), 금일(칠기~도장), 소안(미라...  20150831       70
# 2   장흥 회진(노력~대리)~관산(우산),\r\n고흥 도양(소록~장예)~금산(우두~신촌)...  20150831       16
# 3   장흥 회진(노력~대리)~관산(우산),\r\n고흥 도양(소록~장예)~금산(우두~신촌)...  20150831       80
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '17',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('17red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides     1470  24.8
# 1   Cochlodinium polykrikoides     6000  24.8
# 2   Cochlodinium polykrikoides      120  24.8
# 3   Cochlodinium polykrikoides     2160  24.3
# 4   Cochlodinium polykrikoides      850  24.3
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides     4600  25.4
# 96  Cochlodinium polykrikoides      720  25.4
# 97  Cochlodinium polykrikoides    10000  25.4
# 98  Cochlodinium polykrikoides     3800  25.4
# 99  Cochlodinium polykrikoides      800  25.4
#
#                                     oarea   regdate sdensity      srcode   swt
# 0   남해 고현(염해)~서면(예계), 차면~하동 대도, 월곡 ~하동 중평  20150829       18  2015082901  24.2
# 1   남해 고현(염해)~서면(예계), 차면~하동 대도, 월곡 ~하동 중평  20150829      100  2015082901  24.2
# 2   남해 고현(염해)~서면(예계), 차면~하동 대도, 월곡 ~하동 중평  20150829       20  2015082901  24.2
# 3                         거제 둔덕~법동, 율포~가배  20150829       12  2015082901  23.9
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '18',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('18red_tide_data.csv', index=False)
# Out:
#                          dname edensity          ewt  \
# 0   Cochlodinium polykrikoides     1300         25.4
# 1   Cochlodinium polykrikoides     2500         25.4
# 2   Cochlodinium polykrikoides     4600         26.3
# 3   Cochlodinium polykrikoides      720         26.3
# 4   Cochlodinium polykrikoides    10000         26.3
# ..                         ...      ...          ...
# 95  Cochlodinium polykrikoides      150  여수시 돌산동안~서안
# 96  Cochlodinium polykrikoides     2010  여수시 돌산동안~서안
# 97  Cochlodinium polykrikoides      100  여수시 돌산동안~서안
# 98  Cochlodinium polykrikoides     1290  여수시 돌산동안~서안
# 99  Cochlodinium polykrikoides     3200  여수시 돌산동안~서안
#
#                                          oarea   regdate    sdensity  \
# 0             고흥 도양(장예~화도)~금산(우두~신촌)~도화(지죽~구암)  20150827          20
# 1             고흥 도양(장예~화도)~금산(우두~신촌)~도화(지죽~구암)  20150827         240
# 2   거제 구섬~가배, 율포~곡룡포, 저구~장사도, 구조라~예구, 창원 원전~수치  20150827         150
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '19',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('19red_tide_data.csv', index=False)
# Out:
#                          dname edensity        oarea  \
# 0   Cochlodinium polykrikoides       30  여수시 돌산동안~서안
# 1   Cochlodinium polykrikoides        0  여수시 돌산동안~서안
# 2   Cochlodinium polykrikoides        0  여수시 돌산동안~서안
# 3   Cochlodinium polykrikoides        0         24.4
# 4   Cochlodinium polykrikoides      150         24.4
# ..                         ...      ...          ...
# 95  Cochlodinium polykrikoides     2400           26
# 96  Cochlodinium polykrikoides     3400           26
# 97  Cochlodinium polykrikoides     3000           26
# 98  Cochlodinium polykrikoides     3000           26
# 99  Cochlodinium polykrikoides      350           26
#
#                                     regdate  sdensity      srcode         ewt  \
# 0                                  20150825        10  2015082501        None
# 1                                  20150825         0  2015082501        None
# 2                                  20150825         0  2015082501        None
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '20',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('20red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides      590    26
# 1   Cochlodinium polykrikoides     1300    26
# 2   Cochlodinium polykrikoides     2150  25.3
# 3   Cochlodinium polykrikoides        0  25.3
# 4   Cochlodinium polykrikoides     2400  25.3
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides      750  26.6
# 96  Cochlodinium polykrikoides      850    27
# 97  Cochlodinium polykrikoides     4250    27
# 98  Cochlodinium polykrikoides    13760    27
# 99  Cochlodinium polykrikoides      950    27
#
#                                                 oarea   regdate sdensity  \
# 0             경주(감포), 포항(계원~강사), 영덕(부경~병곡), 울진(후포~진복)  20150824      210
# 1             경주(감포), 포항(계원~강사), 영덕(부경~병곡), 울진(후포~진복)  20150824       30
# 2               완도 고금(도남)~신지(동고)~금일(도장)~약산(득암)~금당(율포)  20150824      150
# 3               완도 고금(도남)~신지(동고)~금일(도장)~약산(득암)~금당(율포)  20150824        0
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '21',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('21red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides    14000    27
# 1   Cochlodinium polykrikoides    13000    27
# 2   Cochlodinium polykrikoides     7200    27
# 3   Cochlodinium polykrikoides      750    27
# 4   Cochlodinium polykrikoides      850    25
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides     4000  25.7
# 96  Cochlodinium polykrikoides     1000  25.7
# 97  Cochlodinium polykrikoides     2230  25.7
# 98  Cochlodinium polykrikoides    12500  25.7
# 99  Cochlodinium polykrikoides      770  25.7
#
#                                   oarea   regdate sdensity      srcode   swt
# 0           장흥 득량만 중부(신동~신상)~하부(대리~노력도)  20150823      100  2015082301  25.2
# 1           장흥 득량만 중부(신동~신상)~하부(대리~노력도)  20150823      244  2015082301  25.2
# 2           장흥 득량만 중부(신동~신상)~하부(대리~노력도)  20150823      100  2015082301  25.2
# 3           장흥 득량만 중부(신동~신상)~하부(대리~노력도)  20150823       80  2015082301  25.2
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '22',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('22red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides     3000  24.4
# 1   Cochlodinium polykrikoides     9700  24.4
# 2   Cochlodinium polykrikoides     4800  24.4
# 3   Cochlodinium polykrikoides     4000  24.4
# 4   Cochlodinium polykrikoides     1000  24.4
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides    10000  26.5
# 96  Cochlodinium polykrikoides     2500  24.3
# 97  Cochlodinium polykrikoides     8000  24.3
# 98  Cochlodinium polykrikoides     4700  24.3
# 99  Cochlodinium polykrikoides     2560  24.3
#
#                                      oarea   regdate sdensity      srcode  \
# 0   고성(하이~자란도~삼산), 통영 사량~오비~한산, 추도~욕지도~소지도  20150821      100  2015082101
# 1   고성(하이~자란도~삼산), 통영 사량~오비~한산, 추도~욕지도~소지도  20150821      120  2015082101
# 2   고성(하이~자란도~삼산), 통영 사량~오비~한산, 추도~욕지도~소지도  20150821      100  2015082101
# 3   고성(하이~자란도~삼산), 통영 사량~오비~한산, 추도~욕지도~소지도  20150821      100  2015082101
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '23',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('23red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides    13000  24.3
# 1   Cochlodinium polykrikoides     4800  24.3
# 2   Cochlodinium polykrikoides    17920  24.3
# 3   Cochlodinium polykrikoides    10000  24.3
# 4   Cochlodinium polykrikoides     2500    26
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides     7000  25.8
# 96  Cochlodinium polykrikoides     1500  25.8
# 97  Cochlodinium polykrikoides      650  25.8
# 98  Cochlodinium polykrikoides     1208  25.8
# 99  Cochlodinium polykrikoides     3500  25.8
#
#                                      oarea   regdate sdensity      srcode  \
# 0            여수 화태~함구미~금오도 서측, 돌산동안~금오도 동측  20150820      200  2015082001
# 1            여수 화태~함구미~금오도 서측, 돌산동안~금오도 동측  20150820     1200  2015082001
# 2            여수 화태~함구미~금오도 서측, 돌산동안~금오도 동측  20150820      100  2015082001
# 3            여수 화태~함구미~금오도 서측, 돌산동안~금오도 동측  20150820      400  2015082001
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '24',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('24red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides     1088  24.4
# 1   Cochlodinium polykrikoides     2500  24.4
# 2   Cochlodinium polykrikoides     2600  24.4
# 3   Cochlodinium polykrikoides     7000  24.4
# 4   Cochlodinium polykrikoides     1500  24.4
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides     2000  25.5
# 96  Cochlodinium polykrikoides     2900  26.5
# 97  Cochlodinium polykrikoides     3840  26.5
# 98  Cochlodinium polykrikoides    10000  26.5
# 99  Cochlodinium polykrikoides      820  26.5
#
#                                        oarea   regdate sdensity      srcode  \
# 0                  여수 월호수도, 군내, 돌산동안(상동~향일암)  20150818       30  2015081801
# 1                  여수 월호수도, 군내, 돌산동안(상동~향일암)  20150818       28  2015081801
# 2                  여수 월호수도, 군내, 돌산동안(상동~향일암)  20150818       80  2015081801
# 3                  여수 월호수도, 군내, 돌산동안(상동~향일암)  20150818      300  2015081801
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '25',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('25red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides     3800  26.5
# 1   Cochlodinium polykrikoides      980  26.5
# 2   Cochlodinium polykrikoides     5000  26.5
# 3   Cochlodinium polykrikoides     2000  26.5
# 4   Cochlodinium polykrikoides      122  27.1
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides     6120    26
# 96  Cochlodinium polykrikoides     1800    26
# 97  Cochlodinium polykrikoides     3000    26
# 98  Cochlodinium polykrikoides     8400    26
# 99  Cochlodinium polykrikoides     2765    26
#
#                                                 oarea   regdate sdensity  \
# 0            거제시 저구~둔덕~가배, 남부 다대~일운(망치~구조라~와현), 덕포~장목  20150817      300
# 1            거제시 저구~둔덕~가배, 남부 다대~일운(망치~구조라~와현), 덕포~장목  20150817       15
# 2            거제시 저구~둔덕~가배, 남부 다대~일운(망치~구조라~와현), 덕포~장목  20150817       10
# 3            거제시 저구~둔덕~가배, 남부 다대~일운(망치~구조라~와현), 덕포~장목  20150817       20
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '26',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('26red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides      130  26.8
# 1   Cochlodinium polykrikoides     6120  26.8
# 2   Cochlodinium polykrikoides     1800  26.8
# 3   Cochlodinium polykrikoides     3000  26.8
# 4   Cochlodinium polykrikoides     8400  26.8
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides     5800  23.8
# 96  Cochlodinium polykrikoides     1600  26.4
# 97  Cochlodinium polykrikoides      250  26.4
# 98  Cochlodinium polykrikoides      110  26.4
# 99  Cochlodinium polykrikoides     5800  26.4
#
#                                          oarea   regdate    sdensity  \
# 0   완도군 신지면~약산~금일, 장흥군 득량만 하부, 고흥군 금산면~도양읍(화도)  20150814           4
# 1   완도군 신지면~약산~금일, 장흥군 득량만 하부, 고흥군 금산면~도양읍(화도)  20150814          60
# 2   완도군 신지면~약산~금일, 장흥군 득량만 하부, 고흥군 금산면~도양읍(화도)  20150814          50
# 3   완도군 신지면~약산~금일, 장흥군 득량만 하부, 고흥군 금산면~도양읍(화도)  20150814          10
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '27',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('27red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides     1600  26.4
# 1   Cochlodinium polykrikoides     3840  26.4
# 2   Cochlodinium polykrikoides     3840  26.4
# 3   Cochlodinium polykrikoides     1120  26.4
# 4   Cochlodinium polykrikoides      250  26.4
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides      600  24.5
# 96  Cochlodinium polykrikoides      300  24.5
# 97  Cochlodinium polykrikoides     2300  24.2
# 98  Cochlodinium polykrikoides     1820  24.2
# 99  Cochlodinium polykrikoides     1980  24.2
#
#                                        oarea  sdensity      srcode  \
# 0                                     부산(남구)        50  2015081399
# 1                                     부산(남구)       142  2015081399
# 2                                     부산(남구)       142  2015081399
# 3                                     부산(남구)        40  2015081399
# 4                                     부산(남구)         5  2015081399
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '28',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('28red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides      600  24.2
# 1   Cochlodinium polykrikoides      300  24.2
# 2   Cochlodinium polykrikoides     2300  23.9
# 3   Cochlodinium polykrikoides     1820  23.9
# 4   Cochlodinium polykrikoides     1980  23.9
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides      800  27.8
# 96  Cochlodinium polykrikoides        3  27.8
# 97  Cochlodinium polykrikoides     1200  27.8
# 98  Cochlodinium polykrikoides      800  27.8
# 99  Cochlodinium polykrikoides     1200  28.1
#
#                               oarea   regdate sdensity      srcode   swt
# 0              거제시 동부면 율포~저구~한산 장사도  20150812      100  2015081201  21.6
# 1              거제시 동부면 율포~저구~한산 장사도  20150812       10  2015081201  21.6
# 2   남해군 서면(장항~노도~염해)~상주면(노도)~남면(유구)  20150812       50  2015081201  22.7
# 3   남해군 서면(장항~노도~염해)~상주면(노도)~남면(유구)  20150812      136  2015081201  22.7
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '29',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('29red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt                oarea   regdate  \
# 0   Cochlodinium polykrikoides      800  28.1          부산(수영구~기장군)  20150809
# 1   Cochlodinium polykrikoides      800  28.1          부산(수영구~기장군)  20150809
# 2   Cochlodinium polykrikoides        3  28.1          부산(수영구~기장군)  20150809
# 3   Cochlodinium polykrikoides     1200  28.1          부산(수영구~기장군)  20150809
# 4   Cochlodinium polykrikoides      800  28.1          부산(수영구~기장군)  20150809
# ..                         ...      ...   ...                  ...       ...
# 95  Cochlodinium polykrikoides      160    27  통영 산양 오비~학림, 한산 장사도  20150805
# 96  Cochlodinium polykrikoides      500    27  통영 산양 오비~학림, 한산 장사도  20150805
# 97  Cochlodinium polykrikoides      500    27  통영 산양 오비~학림, 한산 장사도  20150805
# 98  Cochlodinium polykrikoides      650  26.2  고성군 삼산면~하이면(덕면~맥전포)  20150804
# 99  Cochlodinium polykrikoides      360  26.2  고성군 삼산면~하이면(덕면~맥전포)  20150804
#
#    sdensity      srcode   swt
# ...

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

# API 요청 URL 설정
url = 'http://apis.data.go.kr/1520635/OceanProblemService/getOceanproblemRedTideOccurrenceSpot'

# API 요청 파라미터 설정
params = {
    'ServiceKey': 'QVi9RieurYUJYCnAhtjOHNOJj+q8juTdhUUvQ4lcsbpuG6wsTYCTtQix7GQW14InIKRZWPN3KePvbBcG9OJ5gw==',  # 본인의 서비스 키로 대체
    'numOfRows': '100',  # 한 번에 가져올 데이터 수를 적절하게 설정 (최대 100까지 가능)
    'pageNo': '30',
    'startYmd': '20121223',  # 기간의 시작일 설정 (YYYYMMDD 형식)
    'endYmd': '20190601'  # 기간의 종료일 설정 (YYYYMMDD 형식)
}

# API 요청 보내기
response = requests.get(url, params=params)

# 응답 받은 XML 데이터 파싱
root = ET.fromstring(response.content)

# 모든 적조발생지점 데이터 추출
data = []
columns = []

for item in root.iter('item'):
    row = []
    for child in item:
        row.append(child.text)
        if child.tag not in columns:
            columns.append(child.tag)
    data.append(row)

# DataFrame 생성
df = pd.DataFrame(data, columns=columns)

# DataFrame 출력
print(df)
# DataFrame 저장
df.to_csv('30red_tide_data.csv', index=False)
# Out:
#                          dname edensity   ewt  \
# 0   Cochlodinium polykrikoides      650  25.6
# 1   Cochlodinium polykrikoides      360  25.6
# 2   Cochlodinium polykrikoides      500  25.6
# 3   Cochlodinium polykrikoides       50  25.4
# 4         Heterosigma akashiwo    25000  24.2
# ..                         ...      ...   ...
# 95  Cochlodinium polykrikoides     3500  23.9
# 96  Cochlodinium polykrikoides      500  23.9
# 97  Cochlodinium polykrikoides       50  23.9
# 98  Cochlodinium polykrikoides     5000  23.9
# 99  Cochlodinium polykrikoides     3500  23.6
#
#                                      oarea   regdate sdensity      srcode  \
# 0   경남 통영시 산양 오비 ~ 삼덕 ~ 곤리 , 비진도 ~ 용초도~장사도  20150804       30  2015080401
# 1   경남 통영시 산양 오비 ~ 삼덕 ~ 곤리 , 비진도 ~ 용초도~장사도  20150804        1  2015080401
# 2            경남 통영시 산양 오비도~곤리, 추도, 비진도~오곡도  20150803        5  2015080301
# 3       통영시 추도-산양 연명, 통영시 비진도-오곡도, 거제시 장사도  20150802        5  2015080201
# ...
